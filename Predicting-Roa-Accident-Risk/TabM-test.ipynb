# %% [markdown]
# # TabM

# %%
import pandas as pd

df = pd.read_csv('data/train_pp.csv')
test_df = pd.read_csv('data/test_pp.csv')

X = df.drop(['accident_risk', 'id'], axis=1)
y = df['accident_risk']

# %%
def submission_generator(trained_model):
    test_df_preprocessed = test_df.drop('id', axis=1)
    return pd.concat([test_df['id'], pd.Series(trained_model.predict(test_df_preprocessed))], axis=1).rename({0: 'accident_risk'}, axis=1)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error
import numpy as np
from pytabkit import TabM_D_Regressor

# %%
params = {'batch_size': 'auto',
          'patience': 16,
          'allow_amp': True,
          'arch_type': 'tabm-mini',
          'tabm_k': 32,
          'gradient_clipping_norm': 1.0, 
          'share_training_batches': False,
          'lr': 0.0029993695720154537,
          'weight_decay': 0.023742083301699905,
          'n_blocks': 3,
          'd_block': 448, 
          'dropout': 0.0, 
          'num_emb_type': 'pwl',
          'd_embedding': 32,
          'num_emb_n_bins': 119,
         }

# %%
kf = KFold(5, shuffle=True)
rmses = []
for train_index, test_index in kf.split(X):
    model = TabM_D_Regressor(**params)
    
    X_train = X.iloc[train_index]
    y_train = y.iloc[train_index]
    X_test = X.iloc[test_index]
    y_test = y.iloc[test_index]

    model.fit(X_train, y_train, X_test, y_test)
    
    y_pred = model.predict(X_test)

    rmse = root_mean_squared_error(y_pred, y_test)
    print('---')
    print(rmse)
    rmses.append(rmse)

print(np.mean(rmses))
# Out:
# Setting seed: 1907842928
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 3-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 4-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 5-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 6-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 9-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 10-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 11-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 12-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 13-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 14-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 15-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/nn_models/rtdl_num_embeddings.py:311: UserWarning: The 16-th feature has just two bin edges, which means only one bin. Strictly speaking, using a single bin for the piecewise-linear encoding should not break anything, but it is the same as using sklearn.preprocessing.MinMaxScaler
#   warnings.warn(
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([16224, 1]), y_true.shape=torch.Size([16224, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# ...
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# y_pred.flatten(0, 1).shape=torch.Size([32768, 1]), y_true.shape=torch.Size([32768, 1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 11
#       8 X_test = X.iloc[test_index]
#       9 y_test = y.iloc[test_index]
# ---> 11 model.fit(X_train, y_train, X_test, y_test)
#      13 y_pred = model.predict(X_test)
#      15 rmse = root_mean_squared_error(y_pred, y_test)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/sklearn/sklearn_base.py:407, in AlgInterfaceEstimator.fit(self, X, y, X_val, y_val, val_idxs, cat_indicator, cat_col_names, time_to_fit_in_seconds)
#     403 logger = StdoutLogger(verbosity_level=params.get('verbosity', 0))
#     405 interface_resources = InterfaceResources(n_threads=n_threads, gpu_devices=gpu_devices,
#     406                                          time_in_seconds=time_to_fit_in_seconds)
# --> 407 self.cv_alg_interface_.fit(ds=ds, idxs_list=idxs_list, interface_resources=interface_resources,
#     408                            logger=logger, tmp_folders=tmp_folders, name=self.__class__.__name__)
#     410 # todo: put alg_interface on the CPU after fit() (for saving)? How to do it?
#     411
#     412 # todo: currently, there is only one alg_interface which may fit in parallel (for the NNs),
#     413 #  but we could add an option to make them fit sequentially for RAM reasons or so
#     414 #  (maybe this is best done via a MultiSplitWrapper or so)
#     416 if n_refit > 0:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/alg_interfaces/sub_split_interfaces.py:81, in SingleSplitWrapperAlgInterface.fit(self, ds, idxs_list, interface_resources, logger, tmp_folders, name)
#      75 sub_tmp_folder = tmp_folder / f'sub_split_{i}' if tmp_folder is not None else None
#      76 # don't set fit_params here
#      77 # because we might intentionally not want to set them if use_best_mean_iteration_for_refit==False
#      78 # see get_refit_interfaces()
#      79 # if self.fit_params is not None:
#      80 #     self.sub_split_interfaces[i].fit_params = self.fit_params
# ---> 81 hyper_results = self.sub_split_interfaces[i].fit(ds, sub_split_idxs, interface_resources, logger,
#      82                                                  [sub_tmp_folder], name=name)
#      83 hyper_results = hyper_results[0][0] if hyper_results is not None else []
#      84 hyper_results_list.append(hyper_results)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pytabkit/models/alg_interfaces/tabm_interface.py:373, in TabMSubSplitInterface.fit(self, ds, idxs_list, interface_resources, logger, tmp_folders, name)
#     368     nn.utils.clip_grad.clip_grad_norm_(
#     369         model.parameters(), gradient_clipping_norm
#     370     )
#     372 if grad_scaler is None:
# --> 373     loss.backward()
#     374     optimizer.step()
#     375 else:
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:
